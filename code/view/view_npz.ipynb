# %%
import SimpleITK as sitk
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd

# %%
#npz_file = np.load(r'Z:\grodriguez\CardiacOCT\data-3d\nnUNet_preprocessed\Task504_CardiacOCT\nnUNetData_plans_v2.1_stage1\EST-NEMC-0027_1_001.npz')
#npz_file_data = npz_file['data']

npz_file_new = np.load(r'Z:\grodriguez\CardiacOCT\data-3d\nnUNetData_plans_v2.1_stage1\NLD-AMPH-0003_1_002.npz')
npz_file_data_new = npz_file_new['data']

# %%
npz_file_no_res = np.load(r'Z:\grodriguez\CardiacOCT\data-3d\nnUNet_preprocessed\Task504_CardiacOCT\nnUNetData_plans_v2.1_stage1\NLD-AMPH-0003_1_002.npz')
npz_file_data_no_res = npz_file_no_res['data']

# %%
frame = 1
unique, counts = np.unique(npz_file_data_new[3,:,:,frame], return_counts=True)
print(np.asarray((unique, counts)).T)

#unique, counts = np.unique(npz_file_data_no_res[3,:,:,frame], return_counts=True)
#print(np.asarray((unique, counts)).T)
# Out:
# [[-1.00000e+00  4.77481e+05]]

# %%
frame = 27
unique, counts = np.unique(npz_file_data[3,frame,:,:], return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[-1.00000e+00  1.01915e+05]
#  [ 0.00000e+00  2.49414e+05]
#  [ 1.00000e+00  5.05010e+04]
#  [ 2.00000e+00  2.07200e+04]
#  [ 3.00000e+00  3.30860e+04]
#  [ 6.00000e+00  1.51460e+04]
#  [ 7.00000e+00  6.69900e+03]]

# %%
frame = 27

fig, axes = plt.subplots(2,2, figsize=(15,15))
axes = axes.flatten()

axes[0].imshow(npz_file_data[0,frame,:,:])
axes[1].imshow(npz_file_data[1,frame,:,:])
axes[2].imshow(npz_file_data[2,frame,:,:])
axes[3].imshow(npz_file_data[3,frame,:,:])

# %%
pkl_file = np.load(r'Z:\grodriguez\CardiacOCT\data-3d\nnUNet_preprocessed\Task504_CardiacOCT\nnUNetPlansv2.1_plans_3D.pkl', allow_pickle=True)

# %%
pkl_file.keys()
# Out:
# dict_keys(['num_stages', 'num_modalities', 'modalities', 'normalization_schemes', 'dataset_properties', 'list_of_npz_files', 'original_spacings', 'original_sizes', 'preprocessed_data_folder', 'num_classes', 'all_classes', 'base_num_features', 'use_mask_for_norm', 'keep_only_largest_region', 'min_region_size_per_class', 'min_size_per_class', 'transpose_forward', 'transpose_backward', 'data_identifier', 'plans_per_stage', 'preprocessor_name', 'conv_per_stage'])

# %%
pkl_file['original_spacings']
# Out:
# [array([1., 1., 1.]), array([1., 1., 1.]), array([1., 1., 1.])]
